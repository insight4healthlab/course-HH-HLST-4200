# %% [markdown]
# <a href="https://colab.research.google.com/github/insight4healthlab/course-HH-HLST-4200/blob/main/Python%20/Notebooks/correlation_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# remove the following if you use Jupyter Notebook or other Python IDE

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Import necessary libraries
import pandas as pd
import pyreadstat

# Define the data path (update this if the file is in a different location)
data_path = 'course-HH-HLST-4200/datasets/job_satisfaction.csv'

data_path = '/content/gdrive/MyDrive/' + data_path
# Read the .csv file into a pandas DataFrame
data_frame = pd.read_csv(data_path)

# Display the first few rows of the DataFrame
if data_frame is not None:
    print(data_frame.head())
# Out:
#    Unnamed: 0  Gender   Age  MStatus  Children#  Education  Ethnicity  Yeas#  \
# 0           0     1.0  37.0      1.0        2.0        1.0        0.0    5.0
# 1           1     0.0  56.0      1.0        3.0        1.0        0.0   29.0
# 2           2     1.0  32.0      1.0        3.0        1.0        1.0    8.0
# 3           3     0.0  30.0      1.0        1.0        1.0        1.0    3.0
# 4           4     1.0  41.0      1.0        2.0        1.0        0.0   15.0
#
#    Location  MStatus_Rec  ...  Salary  Promotion  Autonomy  RoleConflict  \
# 0       1.0          0.0  ...     8.0       15.0      18.0           5.0
# 1       3.0          0.0  ...    18.0       41.0      12.0           7.0
# 2       2.0          0.0  ...    28.0       33.0       9.0           9.0
# 3       1.0          0.0  ...    35.0       46.0      15.0          10.0
# 4       3.0          0.0  ...    20.0       39.0      15.0          10.0
#
#    Comfort  WorkLoad  AnyChild  North  Center  South
# ...

# %%
data_frame.head()
# Out:
#    Unnamed: 0  Gender   Age  MStatus  Children#  Education  Ethnicity  Yeas#  \
# 0           0     1.0  37.0      1.0        2.0        1.0        0.0    5.0
# 1           1     0.0  56.0      1.0        3.0        1.0        0.0   29.0
# 2           2     1.0  32.0      1.0        3.0        1.0        1.0    8.0
# 3           3     0.0  30.0      1.0        1.0        1.0        1.0    3.0
# 4           4     1.0  41.0      1.0        2.0        1.0        0.0   15.0
#
#    Location  MStatus_Rec  ...  Salary  Promotion  Autonomy  RoleConflict  \
# 0       1.0          0.0  ...     8.0       15.0      18.0           5.0
# 1       3.0          0.0  ...    18.0       41.0      12.0           7.0
# 2       2.0          0.0  ...    28.0       33.0       9.0           9.0
# 3       1.0          0.0  ...    35.0       46.0      15.0          10.0
# 4       3.0          0.0  ...    20.0       39.0      15.0          10.0
#
#    Comfort  WorkLoad  AnyChild  North  Center  South
# ...

# %%
# Assuming your DataFrame is named 'df'
# Replace 'Salary' and 'Workload' with the actual column names in your DataFrame
correlation = data_frame['Salary'].corr(data_frame['WorkLoad'])

print(f"Pearson correlation between Salary and Workload: {correlation}")
# Out:
# Pearson correlation between Salary and Workload: -0.05605821038233303

# %%
# Interpretation of the p-value
alpha = 0.05  # Significance level
if p_value < alpha:
    print("The correlation is statistically significant.")
else:
    print("The correlation is not statistically significant.")


# Additional information you might find helpful:
# - Covariance: Measures the direction of the linear relationship between two variables.
covariance = data_frame['Salary'].cov(data_frame['WorkLoad'])
print(f"Covariance: {covariance}")
# Out:
# The correlation is not statistically significant.
# Covariance: -0.9051283135331674

# %%
# The Pearson correlation coefficient ranges from -1 to +1.
# -1 indicates a perfect negative linear relationship.
# +1 indicates a perfect positive linear relationship.
# 0 indicates no linear relationship.
print(f"Correlation coefficient: {correlation_coefficient}")

# Explain the result
if abs(correlation_coefficient) > 0.7:
  print("Strong correlation.")
elif abs(correlation_coefficient) > 0.3:
  print("Moderate correlation")
else:
  print("Weak correlation.")
# Out:
# Correlation coefficient: -0.05605821038233302
# Weak correlation.

# %%
from scipy.stats import spearmanr

# Calculate Spearman's rank correlation
correlation, p_value = spearmanr(data_frame['Salary'], data_frame['WorkLoad'])
print(f"Spearman's rank correlation between Salary and Workload: {correlation}")
print(f"P-value: {p_value}")

# Interpretation of the p-value
alpha = 0.05  # Significance level
if p_value < alpha:
    print("The correlation is statistically significant.")
else:
    print("The correlation is not statistically significant.")


# Explain the result (for both Pearson and Spearman's)
if abs(correlation) > 0.7:
  print("Strong Spearman correlation.")
elif abs(correlation) > 0.3:
  print("Moderate Spearman correlation")
else:
  print("Weak Spearman correlation.")
# Out:
# Spearman's rank correlation between Salary and Workload: -0.05769666977959405
# P-value: 0.39661065640911497
# The correlation is not statistically significant.
# Weak Spearman correlation.
